# %%
print("hello")
# Out:
# hello

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\bleed\\Downloads\\matches.csv")

# %%
df=pd.read_csv("C:\\Users\\bleed\\Downloads\\country.csv")

# %%
df=pd.read_csv("C:\\Users\\bleed\\Downloads\\ground.csv")

# %%
df=pd.read_csv("C:\\Users\\bleed\\Downloads\\.csv")

# %%
pd.set_option('display.max_columns',100)

# %%
pd.set_option('display.max_columns',100)

# %%
df
# Out:
#      season_id  match_id                                               slug  \
# 0         4162    185888           england-vs-netherlands-1st-match-group-b
# 1         4162     18582          new-zealand-vs-scotland-2nd-match-group-d
# 2         4162     18583         australia-vs-west-indies-3rd-match-group-c
# 3         4162     18584              bangladesh-vs-india-4th-match-group-a
# 4         4162     18585         scotland-vs-south-africa-5th-match-group-d
# ..         ...       ...                                                ...
# 291      15946    113537  australia-vs-india-51st-match-super-eights-gro...
# 292      15946    113538  afghanistan-vs-bangladesh-52nd-match-super-eig...
# 293      15946    113539         afghanistan-vs-south-africa-1st-semi-final
# 294      15946    113540                    england-vs-india-2nd-semi-final
# 295      15946    113541                        india-vs-south-africa-final
#
# ...

# %%
df["slug"]
# Out:
# 0               england-vs-netherlands-1st-match-group-b
# 1              new-zealand-vs-scotland-2nd-match-group-d
# 2             australia-vs-west-indies-3rd-match-group-c
# 3                  bangladesh-vs-india-4th-match-group-a
# 4             scotland-vs-south-africa-5th-match-group-d
#                              ...
# 291    australia-vs-india-51st-match-super-eights-gro...
# 292    afghanistan-vs-bangladesh-52nd-match-super-eig...
# 293           afghanistan-vs-south-africa-1st-semi-final
# 294                      england-vs-india-2nd-semi-final
# 295                          india-vs-south-africa-final
# Name: slug, Length: 296, dtype: object

# %%
df.loc[[0,1],'slug']
# Out:
# 0     england-vs-netherlands-1st-match-group-b
# 1    new-zealand-vs-scotland-2nd-match-group-d
# Name: slug, dtype: object

# %%
df.iloc[0]
# Out:
# season_id                                                           4162
# match_id                                                          185888
# slug                            england-vs-netherlands-1st-match-group-b
# title                                                 1st Match, Group B
# time_of_day                                                     daynight
# date                                                          05-06-2009
# time                                                            22:00:00
# status                                                            RESULT
# status_description     Netherlands won by 4 wickets (with 0 balls rem...
# winner_team_id                                                      15.0
# toss_winner_team_id                                                 15.0
# toss_choice                                                          2.0
# ground_id                                                             10
# ...

# %%
df['match_id'].value_counts()
# Out:
# match_id
# 113541    1
# 185888    1
# 18582     1
# 18583     1
# 18584     1
#          ..
# 18593     1
# 18591     1
# 18592     1
# 18590     1
# 18589     1
# Name: count, Length: 296, dtype: int64

# %%
df.columns
# Out:
# Index(['season_id', 'match_id', 'slug', 'title', 'time_of_day', 'date', 'time',
#        'status', 'status_description', 'winner_team_id', 'toss_winner_team_id',
#        'toss_choice', 'ground_id', 'team_1_id', 'team_2_id', 'team_1_score',
#        'team_1_scoreInfo', 'team_2_scoreInfo'],
#       dtype='object')

# %%
#show 3 rows from slug to team_2_scoreinfo
df.loc[0:2,'slug':'team_2_scoreInfo']
# Out:
#                                          slug               title time_of_day  \
# 0    england-vs-netherlands-1st-match-group-b  1st Match, Group B    daynight
# 1   new-zealand-vs-scotland-2nd-match-group-d  2nd Match, Group D         day
# 2  australia-vs-west-indies-3rd-match-group-c  3rd Match, Group C         day
#
#          date      time  status  \
# 0  05-06-2009  22:00:00  RESULT
# 1  06-06-2009  14:30:00  RESULT
# 2  06-06-2009  18:30:00  RESULT
#
#                                   status_description  winner_team_id  \
# 0  Netherlands won by 4 wickets (with 0 balls rem...            15.0
# 1  New Zealand won by 7 wickets (with 6 balls rem...             5.0
# 2  West Indies won by 7 wickets (with 25 balls re...             4.0
#
#    toss_winner_team_id  toss_choice  ground_id  team_1_id  team_2_id  \
# 0                 15.0          2.0         10          1         15
# 1                  5.0          2.0         45         30          5
# ...

# %%
india_winning=(df['winner_team_id']==6.0)

# %%
df.loc[india_winning]
# Out:
#      season_id  match_id                                               slug  \
# 3         4162     18584              bangladesh-vs-india-4th-match-group-a
# 11        4162     18591                india-vs-ireland-12th-match-group-a
# 29        5195     26475             afghanistan-vs-india-3rd-match-group-c
# 31        5195     26478            india-vs-south-africa-5th-match-group-c
# 56        6856     42251             afghanistan-vs-india-3rd-match-group-a
# 63        6856     42258                england-vs-india-10th-match-group-a
# 73        6856     42268               india-vs-pakistan-20th-match-group-2
# 77        6856     42272           india-vs-south-africa-24th-match-group-2
# 93        8083     56833               india-vs-pakistan-13th-match-group-2
# 97        8083     56841            india-vs-west-indies-17th-match-group-2
# 104       8083     56855             bangladesh-vs-india-24th-match-group-2
# ...

# %%
#show all the matches that india played
filt=df[df['slug'].str.contains('india')]

# %%
filt
# Out:
#      season_id  match_id                                               slug  \
# 3         4162     18584              bangladesh-vs-india-4th-match-group-a
# 11        4162     18591                india-vs-ireland-12th-match-group-a
# 15        4162     18596            india-vs-west-indies-16th-match-group-e
# 19        4162     18600                england-vs-india-20th-match-group-e
# 23        4162     18604           india-vs-south-africa-24th-match-group-e
# 29        5195     26475             afghanistan-vs-india-3rd-match-group-c
# 31        5195     26478            india-vs-south-africa-5th-match-group-c
# 41        5195     26487              australia-vs-india-15th-match-group-f
# 45        5195     26491            west-indies-vs-india-19th-match-group-f
# 49        5195     26495              india-vs-sri-lanka-23rd-match-group-f
# 56        6856     42251             afghanistan-vs-india-3rd-match-group-a
# ...

# %%
#show all the matches played in 2024
df[df["date"].str.contains("2024")]
# Out:
#      season_id  match_id                                               slug  \
# 241      15946    113487  united-states-of-america-vs-canada-1st-match-g...
# 242      15946    113488  west-indies-vs-papua-new-guinea-2nd-match-group-c
# 243      15946    113489                  namibia-vs-oman-3rd-match-group-b
# 244      15946    113490        south-africa-vs-sri-lanka-4th-match-group-d
# 245      15946    113491            afghanistan-vs-uganda-5th-match-group-c
# 246      15946    113492              england-vs-scotland-6th-match-group-b
# 247      15946    113493             nepal-vs-netherlands-7th-match-group-d
# 248      15946    113494                 india-vs-ireland-8th-match-group-a
# 249      15946    113495       papua-new-guinea-vs-uganda-9th-match-group-c
# 250      15946    113496               australia-vs-oman-10th-match-group-b
# 251      15946    113497  united-states-of-america-vs-pakistan-11th-matc...
# ...

# %%
#show all the matches which team india won in t20 world cup 2024
filtered_df = df[(df["date"].str.contains("2024")) & (df['winner_team_id'] == 6.0)]

# %%
filtered_df
# Out:
#      season_id  match_id                                               slug  \
# 248      15946    113494                 india-vs-ireland-8th-match-group-a
# 259      15946    113505               india-vs-pakistan-19th-match-group-a
# 265      15946    113511  united-states-of-america-vs-india-25th-match-g...
# 283      15946    113529  afghanistan-vs-india-43rd-match-super-eights-g...
# 287      15946    113533  bangladesh-vs-india-47th-match-super-eights-gr...
# 291      15946    113537  australia-vs-india-51st-match-super-eights-gro...
# 294      15946    113540                    england-vs-india-2nd-semi-final
# 295      15946    113541                        india-vs-south-africa-final
#
#                                  title time_of_day        date      time  \
# 248                 8th Match, Group A         day  05-06-2024  20:00:00
# 259                19th Match, Group A         day  09-06-2024  20:00:00
# ...

# %%
team_6_matches_2024 = df[(df["date"].str.contains("2024")) & ((df['winner_team_id'] == 6.0) | (df['team_1_id'] == 6) | (df['team_2_id']==6))]

# %%
team_6_matches_2024
# Out:
#      season_id  match_id                                               slug  \
# 248      15946    113494                 india-vs-ireland-8th-match-group-a
# 259      15946    113505               india-vs-pakistan-19th-match-group-a
# 265      15946    113511  united-states-of-america-vs-india-25th-match-g...
# 273      15946    113519                 canada-vs-india-33rd-match-group-a
# 283      15946    113529  afghanistan-vs-india-43rd-match-super-eights-g...
# 287      15946    113533  bangladesh-vs-india-47th-match-super-eights-gr...
# 291      15946    113537  australia-vs-india-51st-match-super-eights-gro...
# 294      15946    113540                    england-vs-india-2nd-semi-final
# 295      15946    113541                        india-vs-south-africa-final
#
#                                  title time_of_day        date      time  \
# 248                 8th Match, Group A         day  05-06-2024  20:00:00
# ...

# %%
team_6_wins_2024 = team_6_matches_2024['winner_team_id'] == 6.0

# %%
team_6_wins_2024
# Out:
# 248     True
# 259     True
# 265     True
# 273    False
# 283     True
# 287     True
# 291     True
# 294     True
# 295     True
# Name: winner_team_id, dtype: bool

# %%
win_percentage_team_6_2024 = (len(team_6_wins_2024) / len(team_6_matches_2024)) * 100

# %%
win_percentage_team_6_2024
# Out:
# 88.88888888888889
